# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, balanced_accuracy_score, classification_report
from sklearn.datasets import load_breast_cancer

import warnings
warnings.filterwarnings("ignore")

# %%
feature_space = ['mean radius', 'mean texture', 'mean perimeter', 'mean area', 'mean smoothness', 'mean compactness', 'mean concavity']

# %%
data = load_breast_cancer()

df_og = pd.DataFrame(data.data, columns=data.feature_names)
df_og['target'] = data.target

df_og.sample(1)

df_og['target'].value_counts()
# Out:
# target
# 1    357
# 0    212
# Name: count, dtype: int64

# %%
mean_val = df_og['mean radius'].mean()
std_val = df_og['mean radius'].std()

result = f"{mean_val:.2f} ± {std_val:.2f}"
print(result)
# Out:
# 14.13 ± 3.52

# %%
mean_val = df_og['mean texture'].mean()
std_val = df_og['mean texture'].std()

result = f"{mean_val:.2f} ± {std_val:.2f}"
print(result)
# Out:
# 19.29 ± 4.30

# %%
mean_val = df_og['mean perimeter'].mean()
std_val = df_og['mean perimeter'].std()

result = f"{mean_val:.2f} ± {std_val:.2f}"
print(result)
# Out:
# 91.97 ± 24.30

# %%
mean_val = df_og['mean area'].mean()
std_val = df_og['mean area'].std()

result = f"{mean_val:.2f} ± {std_val:.2f}"
print(result)
# Out:
# 654.89 ± 351.91

# %%
mean_val = df_og['mean smoothness'].mean()
std_val = df_og['mean smoothness'].std()

result = f"{mean_val:.2f} ± {std_val:.2f}"
print(result)
# Out:
# 0.10 ± 0.01

# %%
mean_val = df_og['mean compactness'].mean()
std_val = df_og['mean compactness'].std()

result = f"{mean_val:.2f} ± {std_val:.2f}"
print(result)
# Out:
# 0.10 ± 0.05

# %%
mean_val = df_og['mean concavity'].mean()
std_val = df_og['mean concavity'].std()

result = f"{mean_val:.2f} ± {std_val:.2f}"
print(result)
# Out:
# 0.09 ± 0.08
